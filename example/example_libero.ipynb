# %%
from robotdataset import LiberoDataset, batchViz

# %%
dataset = LiberoDataset(
    # tasks=["spatial"],
    episodes=[0,2,3],
)
# Out:
# ---------------------------------------------------------------------------
# DataFilesNotFoundError                    Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 dataset = LiberoDataset(
#       2     # tasks=["spatial"],
#       3     episodes=[0,2,3],
#       4 )
#
# File /rwthfs/rz/cluster/home/yn030245/robotdataset/robotdataset/libero_dataset.py:48, in LiberoDataset.__init__(self, split, tasks, episodes, batch_size, root, delta_timestamps, control_frequency, config_name)
#      45 self.config_name = config_name
#      46 self.root = _get_cache_dir(root)
# ---> 48 hf_dataset = load_hf_dataset(
#      49     self.HF_DATASET,
#      50     split,
#      51     self.root,
#      52     config_name=config_name,
#      53 )
#      54 if tasks is not None:
#      55     hf_dataset = filter_by_tasks(hf_dataset, tasks)
#
# ...
