# %%
from robotdataset import RobomimicDataset, batchViz

# %%
dataset = RobomimicDataset(
                task="lift",
                episodes=[0,1],
)
# Out:
# ...
# Assembling training buffer: 100%|██████████| 2/2 [00:00<00:00, 52.54ep/s]

# %%
dataset.get_modalities()
# Out:
# {'action': {'path': 'action',
#   'kind': 'action',
#   'dtype': 'float32',
#   'shape': (7,),
#   'source': 'storage'},
#  'done': {'path': 'done',
#   'kind': 'generic',
#   'dtype': 'bool',
#   'shape': (1,),
#   'source': 'storage'},
#  'terminated': {'path': 'terminated',
#   'kind': 'generic',
#   'dtype': 'bool',
#   'shape': (1,),
#   'source': 'storage'},
#  'collector/episode_id': {'path': 'collector/episode_id',
#   'kind': 'generic',
#   'dtype': 'int64',
#   'shape': (),
#   'source': 'storage'},
#  'next/reward': {'path': 'next/reward',
#   'kind': 'generic',
#   'dtype': 'float32',
#   'shape': (1,),
#   'source': 'storage'},
#  'next/done': {'path': 'next/done',
#   'kind': 'generic',
#   'dtype': 'bool',
#   'shape': (1,),
#   'source': 'storage'},
#  'next/terminated': {'path': 'next/terminated',
#   'kind': 'generic',
#   'dtype': 'bool',
#   'shape': (1,),
#   'source': 'storage'},
#  'next/observation/object': {'path': 'next/observation/object',
# ...

# %%
batch = next(iter(dataset))

# %%
batchViz(batch,)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File /tmp/yn030245/login23-g-1_159264/venv/lib/python3.13/site-packages/tensordict/_td.py:2823, in TensorDict._get_str(self, key, default, **kwargs)
#    2822 try:
# -> 2823     return self._tensordict[key]
#    2824 except KeyError:
#
# KeyError: 'image'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# File /rwthfs/rz/cluster/home/yn030245/robotdataset/robotdataset/utils/visualization.py:51, in batchViz(batch, key, fps, is_output_video, embed, file_name)
#      50 try:
# ---> 51     video = batch[key_tuple]
#      52 except KeyError:
#
# File /tmp/yn030245/login23-g-1_159264/venv/lib/python3.13/site-packages/tensordict/base.py:639, in TensorDictBase.__getitem__(self, index)
# ...
